# %%
#Problem 1

#assigning data to sales1
sales1<-c(12,14,16,29,30,45,19,20,16, 19, 34, 20)

#creating a poisson distribution and assigning it to sales2
sales2<-rpois(12,34)  # random numbers, Poisson distribution, mean at 34, 12 numbers

#used to set graphical parameters
par(bg="cornsilk")

#plot a graph for the sales1 data using blue color
plot(sales1, col="blue", type="o", ylim=c(0,100), xlab="Month", ylab="Sales" )
title(main="Sales by Month")

#plot dotted lines for the number obtained in the poisson distribution
lines(sales2, type="o", pch=22, lty=2, col="red")

#draw a grid - NA draws no lines, NULL draws lines along the respective axis
grid(nx=NA, ny=NULL)

#declare legend on the plot indicating Sales1 and Sales2 using colors
legend("topright", inset=.05, c("Sales1","Sales2"), fill=c("blue","red"), horiz=TRUE)
# Out:
# Plot with title “Sales by Month”

# %%
#Problem 2

#used to open dialog box to choose the file. works in R studio. does not work in jupyter notebook as jupyter is not interactive.
#sales<-read.table(file.choose(), header=T)

#used to read a text file using file path and indicate that the first row in the header
sales<-read.delim("Data/salesdata.txt", header =TRUE)

#display the data in sales
sales  # to verify that data has been read

#plot a bargraph for the data in sales with total on y-axis and values on x-axis
barplot(as.matrix(sales), main="Sales Data", ylab= "Total",beside=T, col=rainbow(5))
# Out:
#    Sales1 Sales2
# 1  34     45
# 2  23     23
# 3  12     56
# 4  29     34
# 5  34     45
# 6  34     56
# 7  12     89
# 8  80     36
# 9  80     44
# 10 56     66
# 11 55     60
# 12 45     23
# Plot with title “Sales Data”

# %%
#Problem 3

fn1<-boxplot(sales,col=c("orange","green"))$stats

fn<-boxplot(sales,col=c("orange","green"))

fn

# fn2<-boxplot(sales,col=c("orange","green"))$n

# fn3<-boxplot(sales,col=c("orange","green"))$conf

# fn4<-boxplot(sales,col=c("orange","green"))$out

# fn5<-boxplot(sales,col=c("orange","green"))$group

# fn6<-boxplot(sales,col=c("orange","green"))$names

# fn1
# fn2
# fn3
# fn4
# fn5
# fn6

fn1[3,2]
fn1[3,1]

text(1.61, fn1[3,2], paste("Median =", fn1[3,2]), adj=0, cex=0.7)
text(0.61, fn1[3,1],paste("Median =", fn1[3,1]), adj=0, cex=.7)
grid(nx=NA, ny=NA)
# Out:
# $stats
#      [,1] [,2]
# [1,] 12.0   23
# [2,] 26.0   35
# [3,] 34.0   45
# [4,] 55.5   58
# [5,] 80.0   89
# attr(,"class")
#    Sales1
# "integer"
#
# $n
# [1] 12 12
#
# $conf
#          [,1]     [,2]
# [1,] 20.54485 34.50955
# [2,] 47.45515 55.49045
#
# $out
# numeric(0)
#
# $group
# numeric(0)
#
# $names
# [1] "Sales1" "Sales2"
# [1] 45
# [1] 34
# plot without title

# %%
#Problem 4
#used to read a csv file using file path
fb1<-read.csv("Data/FB.csv")
aapl1<-read.csv("Data/AAPL.csv")

par(bg="cornsilk")
plot(aapl1$Adj.Close, col="blue", type="o", ylim=c(0,300), xlab="Days", ylab="Price" )
lines(fb1$Adj.Close, type="o", pch=22, lty=2, col="red")
legend("topright", inset=0.05, c("Apple","Facebook"), fill=c("blue","red"), horiz=TRUE)

#plot a histogram with values on x axis and  frequency on y axis
#Histograms are NOT barplots
#Histograms are used to show distributions of variables while bar charts are used to compare variables.
hist(aapl1$Adj.Close, xlab="Apple Adj Close",main="Histogram for Apple", col=rainbow(8))

#below statement oes not work as the aapl1 data does not any other data to compare
#barplot(as.matrix(aapl1), main="Sales Data", ylab= "Total",beside=T, col=rainbow(5))
# Out:
# plot without title
# Plot with title “Histogram for Apple”

# %%
install.packages('ggplot2')
# Out:
# also installing the dependencies ‘lattice’, ‘colorspace’, ‘assertthat’, ‘utf8’, ‘nlme’, ‘Matrix’, ‘labeling’, ‘munsell’, ‘R6’, ‘RColorBrewer’, ‘cli’, ‘fansi’, ‘pillar’, ‘pkgconfig’, ‘gtable’, ‘lazyeval’, ‘MASS’, ‘mgcv’, ‘plyr’, ‘reshape2’, ‘rlang’, ‘scales’, ‘tibble’, ‘viridisLite’, ‘withr’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
#Problem 5

#data() function displays all the datasets available that come with R
#data(package="ggplot2") ->> this displays all datasets in the ggplot2 package.
data()

#library() function is used to import a particular library that can be worked upon. ggplot2 library has the mpg dataset.
library(ggplot2)

#summary function gives a summary about the dataset.
summary(mpg)

#attach() function attaches dataset to R search path. It is used to access the data in dataset directly without using the syntax "dataset_name$data"
attach(mpg)

#head() gives us first few rows of the dataset
head(mpg)

#detaches the dataset from the search path which is an important step. every dataset attached should be detached.
detach(mpg)
# Out:
#  manufacturer          model               displ            year
#  Length:234         Length:234         Min.   :1.600   Min.   :1999
#  Class :character   Class :character   1st Qu.:2.400   1st Qu.:1999
#  Mode  :character   Mode  :character   Median :3.300   Median :2004
#                                        Mean   :3.472   Mean   :2004
#                                        3rd Qu.:4.600   3rd Qu.:2008
#                                        Max.   :7.000   Max.   :2008
#       cyl           trans               drv                 cty
#  Min.   :4.000   Length:234         Length:234         Min.   : 9.00
#  1st Qu.:4.000   Class :character   Class :character   1st Qu.:14.00
#  Median :6.000   Mode  :character   Mode  :character   Median :17.00
#  Mean   :5.889                                         Mean   :16.86
#  3rd Qu.:8.000                                         3rd Qu.:19.00
#  Max.   :8.000                                         Max.   :35.00
#       hwy             fl               class
#  Min.   :12.00   Length:234         Length:234
#  1st Qu.:18.00   Class :character   Class :character
#  Median :24.00   Mode  :character   Mode  :character
#  Mean   :23.44
#  3rd Qu.:27.00
#  Max.   :44.00
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
library(datasets)
head(sunspots,n=12)
plot(sunspots)
# Out:
#  [1]  58.0  62.6  70.0  55.7  85.0  83.5  94.8  66.3  75.9  75.5 158.6  85.2
# plot without title

# %%
install.packages('ggmap')
# Out:
# also installing the dependencies ‘sys’, ‘askpass’, ‘Rcpp’, ‘tidyselect’, ‘BH’, ‘plogr’, ‘curl’, ‘mime’, ‘openssl’, ‘RgoogleMaps’, ‘png’, ‘rjson’, ‘jpeg’, ‘dplyr’, ‘bitops’, ‘httr’, ‘purrr’, ‘tidyr’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages('maptools')
# Out:
# also installing the dependencies ‘sp’, ‘foreign’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages('maps')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
Sys.setenv(Google_Api_Key="AIzaSyCWSqZEvz--Wc4EdSRSY0LeUdQygtCDSLA")

# %%
#Problem 6

#importing libraries
library("ggmap")
library("maptools")
library('maps')
# Out:
# Loading required package: ggplot2
# Google's Terms of Service: https://cloud.google.com/maps-platform/terms/.
# Please cite ggmap if you use it! See citation("ggmap") for details.
# Loading required package: sp
# Checking rgeos availability: FALSE
#  	Note: when rgeos is not available, polygon geometry 	computations in maptools depend on gpclib,
#  	which has a restricted licence. It is disabled by default;
#  	to enable gpclib, type gpclibPermit()

# %%
install.packages("devtools")
# Out:
# also installing the dependencies ‘git2r’, ‘usethis’
#
# Warning message in install.packages("devtools"):
# “installation of package ‘git2r’ had non-zero exit status”Warning message in install.packages("devtools"):
# “installation of package ‘usethis’ had non-zero exit status”Warning message in install.packages("devtools"):
# “installation of package ‘devtools’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(devtools)

# %%
install.packages("ggmap")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
devtools::install_github("dkahle/ggmap")
# Out:
# Downloading GitHub repo dkahle/ggmap@master
# from URL https://api.github.com/repos/dkahle/ggmap/zipball/master
# Installation failed: error in running command

# %%
#accessing google api to use with geolocation servies
api_key<-Sys.getenv("Google_Api_Key")
register_google(key = "AIzaSyCWSqZEvz--Wc4EdSRSY0LeUdQygtCDSLA")

# %%
#plot a map of the world and mark the visited cities in that map

visited <- c("SFO", "Chennai", "London", "Melbourne", "Lima,Peru", "Johannesbury, SA")

#get geocodes on each of the cities mentioned in the visited list
ll.visited <- geocode(visited)

#set x and y parameters as the latitude and longitude values for each city
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat

#display the map of the world
map("world", fill=TRUE, col="white", bg="lightblue", ylim=c(-60, 90), mar=c(0,0,0,0))

#plot points on that map for the cities. pch takes different arguments for different shapes to mark thhe cities
points(visit.x,visit.y, col="red", pch=19)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SFO&key=xxx--Wc4EdSRSY0LeUdQygtCDSLA
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Chennai&key=xxx--Wc4EdSRSY0LeUdQygtCDSLA
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=London&key=xxx--Wc4EdSRSY0LeUdQygtCDSLA
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Melbourne&key=xxx--Wc4EdSRSY0LeUdQygtCDSLA
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Lima,Peru&key=xxx--Wc4EdSRSY0LeUdQygtCDSLA
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Johannesbury,+SA&key=xxx--Wc4EdSRSY0LeUdQygtCDSLA
# plot without title

# %%
visited <- c("SFO", "New York", "Buffalo", "Dallas, TX")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("state", fill=TRUE, col=rainbow(50), bg="lightblue", mar=c(0,0,0,0))

#cex denotes the size of the marking symbol on the map
#points(visit.x,visit.y, col="yellow", pch=6, cex = 2)
# Out:
# Error: Google now requires an API key.
#        See ?register_google for details.
# Traceback:
#
# 1. geocode(visited)
# 2. stop("Google now requires an API key.", "\n       See ?register_google for details.",
#  .     call. = FALSE)

# %%
visited <- c("Chennai", "Hyderabad", "Mumbai", "Kolkata","Delhi","Vizag")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("world",region="India", fill=TRUE, col=9:10, bg="lightblue", mar=c(0,0,0,0))

points(visit.x,visit.y, col="blue", pch=6, cex = 2)
# Out:
# Error: Google now requires an API key.
#        See ?register_google for details.
# Traceback:
#
# 1. geocode(visited)
# 2. stop("Google now requires an API key.", "\n       See ?register_google for details.",
#  .     call. = FALSE)

# %%
#Problem 7

attach(mtcars)
head(mtcars)

#draw scatter plots for specific columns in dataset
plot(mtcars[c(1,3,4,5,6)], main="MTCARS Data")
plot(mtcars[c(1,3,4,6)], main="MTCARS Data")
plot(mtcars[c(1,3,4,6)], col=rainbow(5),main="MTCARS Data")
# Out:
# The following object is masked from package:ggplot2:
#
#     mpg
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1
# plot without title
# plot without title
# plot without title

# %%
#Problem 8

library(ggplot2)
ggplot(mtcars, aes(x=mpg, y=disp)) + geom_point()
# Out:
# plot without title
